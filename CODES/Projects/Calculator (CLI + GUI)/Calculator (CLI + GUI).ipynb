# %% [markdown]
# # Import layer

# %%
# Out:
# ERROR: unknown command "import"

# %% [markdown]
# # Functions layer

# %%
def add(a,b):
    return a+b

def sub(a,b):
    return a-b

def mul(a,b):
    return a*b

def div(a,b):
    if(a==0 or b == 0):
        print("division error")
    else:
        return a/b

# %% [markdown]
# # VARIABLES

# %%
choice = ""

# %% [markdown]
# # Coding layer

# %% [markdown]
# # CLI CALCULATOR

# %%
while True:
    #choice = input(
        "\nEnter operation (add, sub, mul, div) or type stop:\n"
    ).lower()

    if "stop" in choice:
        print("Calculator stopped.")
        break

    try:
        #num1 = int(input("Enter first number: "))
        #num2 = int(input("Enter second number: "))
    except ValueError:
        print("Invalid number input. Try again.")
        continue

    # Keyword matching using ANY
    if any(word in choice for word in ["add", "sum", "plus", "+"]):
        print("Result:", add(num1, num2))

    elif any(word in choice for word in ["sub", "minus", "subtract", "-"]):
        print("Result:", sub(num1, num2))

    elif any(word in choice for word in ["mul", "into", "*"]):
        print("Result:", mul(num1, num2))

    elif any(word in choice for word in ["div", "division", "/", "bhag"]):
        print("Result:", div(num1, num2))

    else:
        print("Operation not recognized.")
# Out:
# Invalid number input. Try again.
# Invalid number input. Try again.
# Invalid number input. Try again.
# Invalid number input. Try again.
# Invalid number input. Try again.
# Invalid number input. Try again.
# Invalid number input. Try again.
# Calculator stopped.

# %% [markdown]
# # GUI CALCULATOR

# %% [markdown]
# ## Install Libraries

# %%
# !pip install pyside6
# Out:
# ...
#   Using cached pyside6-6.11.1-cp310-abi3-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached shiboken6-6.11.1-cp310-abi3-win_amd64.whl.metadata (2.5 kB)
# ...
#   Using cached pyside6_essentials-6.11.1-cp310-abi3-win_amd64.whl.metadata (3.8 kB)
# ...
#   Using cached pyside6_addons-6.11.1-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Using cached pyside6-6.11.1-cp310-abi3-win_amd64.whl (578 kB)
# Using cached pyside6_addons-6.11.1-cp310-abi3-win_amd64.whl (168.8 MB)
# Using cached pyside6_essentials-6.11.1-cp310-abi3-win_amd64.whl (77.5 MB)
# Using cached shiboken6-6.11.1-cp310-abi3-win_amd64.whl (1.2 MB)
# ...
#
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
#    ---------- ----------------------------- 1/4 [PySide6_Essentials]
# ...

# %% [markdown]
# ## IMPORT LAYER

# %%
from PySide6.QtWidgets import QApplication, QMainWindow, QLineEdit, QVBoxLayout, QWidget

# %% [markdown]
# ## Program

# %%
calculatorapp = QApplication(sys.argv)

parent = QWidget()

text, ok = QInputDialog.getText(parent, "Input Box Title", "Enter your name:")
