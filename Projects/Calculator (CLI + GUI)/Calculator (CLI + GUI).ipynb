# %% [markdown]
# # Import layer

# %% [markdown]
# # Functions layer

# %%
def add(a,b):
    return a+b

def sub(a,b):
    return a-b

def mul(a,b):
    return a*b

def div(a,b):
    
    return a/b

# %% [markdown]
# # VARIABLES

# %%
choice = ""

# %% [markdown]
# # Coding layer

# %%
while True:
    choice = input(
        "\nEnter operation (add, sub, mul, div) or type stop:\n"
    ).lower()

    if "stop" in choice:
        print("Calculator stopped.")
        break

    try:
        num1 = int(input("Enter first number: "))
        num2 = int(input("Enter second number: "))
    except ValueError:
        print("Invalid number input. Try again.")
        continue

    # Keyword matching using ANY
    if any(word in choice for word in ["add", "sum", "plus", "+"]):
        print("Result:", add(num1, num2))

    elif any(word in choice for word in ["sub", "minus", "subtract", "-"]):
        print("Result:", sub(num1, num2))

    elif any(word in choice for word in ["mul", "into", "*"]):
        print("Result:", mul(num1, num2))

    elif any(word in choice for word in ["div", "division", "/", "bhag"]):
        print("Result:", div(num1, num2))

    else:
        print("Operation not recognized.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       2     choice = input("enter the name of operation you want to perform:- \n1.add\n2.sub\n3.mul\n4.div\n5.stop\n\nEnter : ").lower()
#       3     if(choice=="stop"):
#       4         break
#       5     else:
# ----> 6         num1 = int(input("enter you first digit : "))
#       7         num2 = int(input("enter you second digit : "))
#       8
#       9         if(choice in ["add","sum","plus","+"]):
#
# ValueError: invalid literal for int() with base 10: ''
